# %% [markdown]
# # Credit Card Approval Prediction
#
# Credit score cards are a common risk control method in the financial industry.
#
# It uses personal information and data submitted by credit card applicants to predict the probability of future defaults and credit card borrowings.
#
# The bank is able to decide whether to issue a credit card to the applicant. Credit scores can objectively quantify the magnitude of risk.

# %% [markdown]
# # Questions to Answer

# %% [markdown]
# ##1.Why is your proposal important in today’s world? How predicting a good client is worthy for a bank?
#
# Ans - My proposal is important in today's world because it can help banks to attract and **retain good clients**. By predicting which customers are more likely to be profitable, banks can focus their marketing and sales efforts on those customers. This can lead to increased revenue and profits.
#
# Here are some of the specific benefits of predicting good clients for banks:
#
# **Increased customer acquisition**: Banks can use predictive models to identify potential customers who are more likely to be profitable. This can help banks to target their marketing campaigns more effectively and acquire more customers.
#
# **Reduced customer churn:** Banks can use predictive models to identify customers who are at risk of churning. This can help banks to take proactive steps to retain these customers, such as offering them discounts or special services.
#
# **Improved risk management**: Banks can use predictive models to assess the risk of lending to a particular customer. This can help banks to make more informed lending decisions and reduce their exposure to losses.
#
# **Personalized marketing:** Banks can use predictive models to create personalized marketing campaigns that are more likely to appeal to specific customers. This can help banks to increase customer engagement and improve customer satisfaction.
#
# In addition to the above, here are some other strategies that banks can adopt to attract quality clients:
#
# **Focus on customer service** : This means being responsive to customer needs, resolving issues quickly and efficiently, and going the extra mile to make customers happy.
#
# **Offer competitive products and services** : This could include things like high-interest savings accounts, low-interest loans, and convenient online banking services.
#
# **Use technology to their advantage** : This could include things like using mobile apps, online banking, and chatbots to make it easier for customers to do their banking.
#
# **Build relationships with customers** : This means getting to know their customers' needs and preferences, and offering them personalized products and services.

# %% [markdown]
# #2. How is it going to impact the banking sector?
#
# Ans - The proposed project's impact on the banking sector can be substantial and transformative in several ways:
#
# **Enhanced Risk Management**
#
# **Improved Profitability**
#
# **Efficient Resource Allocation**
#
# **Competitive Advantage**
#
# **Financial Inclusion**
#
# **Responsible Lending**
#
# **Strengthened Regulatory Compliance**
#
# **Customer Satisfaction and Loyalty**
#
# **Data-Driven Decision-Making**
#
# **Economic Impact**

# %% [markdown]
# #3. If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India.
#
# Ans - There are a few gaps in the knowledge about predicting good clients in the banking sector in India.
#
# **Data availability:** The availability of data is a major challenge in India. Many banks do not have access to the data they need to build predictive models. This is because the data is often siloed or in different formats.
#
# **Data quality:** The quality of data is also a challenge. The data may be incomplete, inaccurate, or outdated. This can make it difficult to build accurate predictive models.
#
# **Modeling techniques:** There is no one-size-fits-all approach to modeling. The best modeling technique will vary depending on the data and the problem that is being solved.
#
# **Interpretation of results**: It can be difficult to interpret the results of predictive models. This is because the models are often complex and the results may not be intuitive.
#
#
# ####My proposed method can be helpful to fill these gaps in knowledge in the following ways:
#
#
#
# **Data collection:** I can help banks to collect the data they need to build predictive models. I can do this by using a variety of techniques, such as surveys, interviews, and data mining.
#
# **Data cleaning:** I can help banks to clean and prepare the data for modeling. This includes removing outliers, imputing missing values, and standardizing the data.
#
# **Modeling**: I can help banks to choose the best modeling technique for their data and problem. I can also help them to build and evaluate the models.
#
# **Interpretation of results:** I can help banks to interpret the results of the models. This includes explaining the meaning of the results and how they can be used to make decisions.

# %% [markdown]
# ###Build a machine learning model to predict if an applicant is 'good' or 'bad' client, different from other tasks, the definition of 'good' or 'bad' is not given.
#
#     1 Load credit card dataset
#     2 Inspecting the dataset
#     3 Handling the missing values
#     4 Preprocessing the data
#     5 Data Analysis Using Visualization
#     6 Splitting the dataset into train and test sets
#     7 Preprocessing the data
#     8 Making predictions and evaluating performance
#     9 Grid searching and making the model perform better
#     10 Finding the best performing model

# %% [markdown]
# ####This dataset's objective is predicting whether an applicant's credit card approval will be approved or not. The dataset contains applicants' basic information
#
#
#
# Features name: (Credit_Card.csv)
#
# Ind_ID: Client ID
#
# Gender: Gender information
#
# Car_owner: Having car or not
#
# Propert_owner: Having property or not
#
# Children: Count of children
#
# Annual_income: Annual income
#
# Type_Income: Income type
#
# Education: Education level
#
# Marital_status: Marital_status
#
# Housing_type: Living style
#
# Birthday_count: Use backward count from current day (0), -1 means yesterday.
#
# Employed_days: Start date of employment. Use backward count from current day (0). Positive value means, individual is currently unemployed.
#
# Mobile_phone: Any mobile phone
#
# Work_phone: Any work phone
#
# Phone: Any phone number
#
# EMAIL_ID: Any email ID
#
# Type_Occupation: Occupation
#
# Family_Members: Family size
#
# Label: 0 is application approved and 1 is application rejected.

# %% [markdown]
# # Imports

# %%
# Importing File Operations
import numpy as np
import pandas as pd

# Importing Ploting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import missingno as msno

# Importing Warnings Ignore
import warnings
warnings.filterwarnings('ignore')

# Machine Learning
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Data Import

# %%
data1 = pd.read_csv('Credit_card.csv')
data1
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# 1     Commercial associate               Higher education
# 2     Commercial associate               Higher education
# 3     Commercial associate               Higher education
# 4     Commercial associate               Higher education
# ...                    ...                            ...
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type  Birthday_count  Employed_days  \
# 0                  Married  House / apartment        -18772.0         365243
# 1                  Married  House / apartment        -13557.0           -586
# 2                  Married  House / apartment             NaN           -586
# 3                  Married  House / apartment        -13557.0           -586
# 4                  Married  House / apartment        -13557.0           -586
# ...                    ...                ...             ...            ...
# 1543               Married  House / apartment        -11957.0          -2182
# 1544  Single / not married  House / apartment        -10229.0          -1209
# 1545               Married  House / apartment        -13174.0          -2477
# 1546        Civil marriage  House / apartment        -15292.0           -645
# 1547               Married  House / apartment        -16601.0          -2859
#
#       Mobile_phone  Work_Phone  Phone  EMAIL_ID Type_Occupation  \
# 0                1           0      0         0             NaN
# 1                1           1      1         0             NaN
# 2                1           1      1         0             NaN
# 3                1           1      1         0             NaN
# 4                1           1      1         0             NaN
# ...            ...         ...    ...       ...             ...
# 1543             1           0      0         0        Managers
# 1544             1           0      0         0     Accountants
# 1545             1           0      0         0        Managers
# 1546             1           1      1         0         Drivers
# 1547             1           0      0         0             NaN
#
#       Family_Members
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# ...              ...
# 1543               2
# 1544               1
# 1545               4
# 1546               2
# 1547               2
#
# [1548 rows x 18 columns]

# %%
data2 = pd.read_csv('Credit_card_label.csv')
data2
# Out:
#        Ind_ID  label
# 0     5008827      1
# 1     5009744      1
# 2     5009746      1
# 3     5009749      1
# 4     5009752      1
# ...       ...    ...
# 1543  5028645      0
# 1544  5023655      0
# 1545  5115992      0
# 1546  5118219      0
# 1547  5053790      0
#
# [1548 rows x 2 columns]

# %%
df_raw = pd.merge(data1,data2, on='Ind_ID' ,how = 'inner')
df_raw
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# 1     Commercial associate               Higher education
# 2     Commercial associate               Higher education
# 3     Commercial associate               Higher education
# 4     Commercial associate               Higher education
# ...                    ...                            ...
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type  Birthday_count  Employed_days  \
# 0                  Married  House / apartment        -18772.0         365243
# 1                  Married  House / apartment        -13557.0           -586
# 2                  Married  House / apartment             NaN           -586
# 3                  Married  House / apartment        -13557.0           -586
# 4                  Married  House / apartment        -13557.0           -586
# ...                    ...                ...             ...            ...
# 1543               Married  House / apartment        -11957.0          -2182
# 1544  Single / not married  House / apartment        -10229.0          -1209
# 1545               Married  House / apartment        -13174.0          -2477
# 1546        Civil marriage  House / apartment        -15292.0           -645
# 1547               Married  House / apartment        -16601.0          -2859
#
#       Mobile_phone  Work_Phone  Phone  EMAIL_ID Type_Occupation  \
# 0                1           0      0         0             NaN
# 1                1           1      1         0             NaN
# 2                1           1      1         0             NaN
# 3                1           1      1         0             NaN
# 4                1           1      1         0             NaN
# ...            ...         ...    ...       ...             ...
# 1543             1           0      0         0        Managers
# 1544             1           0      0         0     Accountants
# 1545             1           0      0         0        Managers
# 1546             1           1      1         0         Drivers
# 1547             1           0      0         0             NaN
#
#       Family_Members  label
# 0                  2      1
# 1                  2      1
# 2                  2      1
# 3                  2      1
# 4                  2      1
# ...              ...    ...
# 1543               2      0
# 1544               1      0
# 1545               4      0
# 1546               2      0
# 1547               2      0
#
# [1548 rows x 19 columns]

# %%
df = df_raw.copy()
df
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# 1     Commercial associate               Higher education
# 2     Commercial associate               Higher education
# 3     Commercial associate               Higher education
# 4     Commercial associate               Higher education
# ...                    ...                            ...
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type  Birthday_count  Employed_days  \
# 0                  Married  House / apartment        -18772.0         365243
# 1                  Married  House / apartment        -13557.0           -586
# 2                  Married  House / apartment             NaN           -586
# 3                  Married  House / apartment        -13557.0           -586
# 4                  Married  House / apartment        -13557.0           -586
# ...                    ...                ...             ...            ...
# 1543               Married  House / apartment        -11957.0          -2182
# 1544  Single / not married  House / apartment        -10229.0          -1209
# 1545               Married  House / apartment        -13174.0          -2477
# 1546        Civil marriage  House / apartment        -15292.0           -645
# 1547               Married  House / apartment        -16601.0          -2859
#
#       Mobile_phone  Work_Phone  Phone  EMAIL_ID Type_Occupation  \
# 0                1           0      0         0             NaN
# 1                1           1      1         0             NaN
# 2                1           1      1         0             NaN
# 3                1           1      1         0             NaN
# 4                1           1      1         0             NaN
# ...            ...         ...    ...       ...             ...
# 1543             1           0      0         0        Managers
# 1544             1           0      0         0     Accountants
# 1545             1           0      0         0        Managers
# 1546             1           1      1         0         Drivers
# 1547             1           0      0         0             NaN
#
#       Family_Members  label
# 0                  2      1
# 1                  2      1
# 2                  2      1
# 3                  2      1
# 4                  2      1
# ...              ...    ...
# 1543               2      0
# 1544               1      0
# 1545               4      0
# 1546               2      0
# 1547               2      0
#
# [1548 rows x 19 columns]

# %% [markdown]
# # EXPLORATORT DATA ANALYSIS(EDA)

# %% [markdown]
# ## Describe

# %%
# decribing and transposing the data

df.describe(include='all').T
# Out:
#                   count unique                            top  freq  \
# Ind_ID           1548.0    NaN                            NaN   NaN
# GENDER             1541      2                              F   973
# Car_Owner          1548      2                              N   924
# Propert_Owner      1548      2                              Y  1010
# CHILDREN         1548.0    NaN                            NaN   NaN
# Annual_income    1525.0    NaN                            NaN   NaN
# Type_Income        1548      4                        Working   798
# EDUCATION          1548      5  Secondary / secondary special  1031
# Marital_status     1548      5                        Married  1049
# Housing_type       1548      6              House / apartment  1380
# Birthday_count   1526.0    NaN                            NaN   NaN
# Employed_days    1548.0    NaN                            NaN   NaN
# Mobile_phone     1548.0    NaN                            NaN   NaN
# Work_Phone       1548.0    NaN                            NaN   NaN
# Phone            1548.0    NaN                            NaN   NaN
# EMAIL_ID         1548.0    NaN                            NaN   NaN
# Type_Occupation    1060     18                       Laborers   268
# Family_Members   1548.0    NaN                            NaN   NaN
# label            1548.0    NaN                            NaN   NaN
#
#                            mean            std        min         25%  \
# Ind_ID           5078920.351421   41717.587742  5008827.0  5045069.75
# GENDER                      NaN            NaN        NaN         NaN
# Car_Owner                   NaN            NaN        NaN         NaN
# Propert_Owner               NaN            NaN        NaN         NaN
# CHILDREN               0.412791       0.776691        0.0         0.0
# Annual_income      191399.32623  113252.997656    33750.0    121500.0
# Type_Income                 NaN            NaN        NaN         NaN
# EDUCATION                   NaN            NaN        NaN         NaN
# Marital_status              NaN            NaN        NaN         NaN
# Housing_type                NaN            NaN        NaN         NaN
# Birthday_count    -16040.342071    4229.503202   -24946.0    -19553.0
# Employed_days      59364.689922  137808.062701   -14887.0     -3174.5
# Mobile_phone                1.0            0.0        1.0         1.0
# Work_Phone              0.20801       0.406015        0.0         0.0
# Phone                  0.309432       0.462409        0.0         0.0
# EMAIL_ID               0.092377       0.289651        0.0         0.0
# Type_Occupation             NaN            NaN        NaN         NaN
# Family_Members         2.161499       0.947772        1.0         2.0
# label                  0.113049       0.316755        0.0         0.0
#
#                        50%        75%        max
# Ind_ID           5078841.5  5115673.0  5150412.0
# GENDER                 NaN        NaN        NaN
# Car_Owner              NaN        NaN        NaN
# Propert_Owner          NaN        NaN        NaN
# CHILDREN               0.0        1.0       14.0
# Annual_income     166500.0   225000.0  1575000.0
# Type_Income            NaN        NaN        NaN
# EDUCATION              NaN        NaN        NaN
# Marital_status         NaN        NaN        NaN
# Housing_type           NaN        NaN        NaN
# Birthday_count    -15661.5   -12417.0    -7705.0
# Employed_days      -1565.0    -431.75   365243.0
# Mobile_phone           1.0        1.0        1.0
# Work_Phone             0.0        0.0        1.0
# Phone                  0.0        1.0        1.0
# EMAIL_ID               0.0        0.0        1.0
# Type_Occupation        NaN        NaN        NaN
# Family_Members         2.0        3.0       15.0
# label                  0.0        0.0        1.0

# %% [markdown]
# ## Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
#  17  Family_Members   1548 non-null   int64
#  18  label            1548 non-null   int64
# dtypes: float64(2), int64(9), object(8)
# memory usage: 241.9+ KB

# %% [markdown]
# ## Unique Values & there Count

# %%
for i in df.columns:
    print(f'\n{i} : \n', df[i].unique(), '\n')
    print(df[i].value_counts())
    print('\n----------------------------------------------------------------------')
# Out:
# Ind_ID :
#  [5008827 5009744 5009746 ... 5115992 5118219 5053790]
#
# 5008827    1
# 5142163    1
# 5024925    1
# 5143560    1
# 5068648    1
#           ..
# 5148792    1
# 5142290    1
# 5095324    1
# 5118270    1
# 5053790    1
# Name: Ind_ID, Length: 1548, dtype: int64
#
# ----------------------------------------------------------------------
#
# GENDER :
#  ['M' 'F' nan]
#
# F    973
# M    568
# Name: GENDER, dtype: int64
#
# ----------------------------------------------------------------------
#
# Car_Owner :
#  ['Y' 'N']
#
# N    924
# Y    624
# Name: Car_Owner, dtype: int64
#
# ----------------------------------------------------------------------
#
# Propert_Owner :
#  ['Y' 'N']
#
# Y    1010
# N     538
# Name: Propert_Owner, dtype: int64
#
# ----------------------------------------------------------------------
#
# CHILDREN :
#  [ 0  1  2  4  3 14]
#
# 0     1091
# 1      305
# 2      134
# 3       16
# 4        1
# 14       1
# Name: CHILDREN, dtype: int64
#
# ----------------------------------------------------------------------
#
# Annual_income :
#  [ 180000.   315000.        nan  450000.    90000.   472500.   270000.
#   126000.   202500.   157500.   112500.   540000.   292500.   135000.
#    76500.   215100.   225000.    67500.   171000.   103500.    99000.
#   391500.    65250.    72900.   360000.   256500.   675000.   247500.
#    85500.   121500.   130500.   211500.    81000.    72000.   148500.
#   162000.   195750.   585000.   216000.   306000.   108000.    63000.
#    45000.   337500.   131400.   117000.   445500.   234000.  1575000.
#   144000.    67050.    73350.   193500.   900000.    94500.   198000.
#    54000.   166500.   167400.   153000.   423000.   243000.   283500.
#   252000.   495000.   612000.    36000.   139500.   133650.   427500.
#   261000.   231750.    90900.    45900.   119250.    58500.   328500.
#   787500.   594000.   119700.    69372.    37800.   387000.   207000.
#   189000.   333000.   105750.   382500.   141750.    40500.   405000.
#    44550.   301500.   351000.   175500.   121900.5  238500.    33750.
#   116100.   297000.   630000.   418500.    83250.   173250.   274500.
#   115200.    56250.    95850.   185400.   810000.   184500.   165600.
#   114750.    47250.    49500.    69750. ]
#
# 135000.0    170
# 112500.0    144
# 180000.0    137
# 157500.0    125
# 225000.0    119
#            ...
# 119700.0      1
# 69372.0       1
# 37800.0       1
# 333000.0      1
# 69750.0       1
# Name: Annual_income, Length: 115, dtype: int64
#
# ----------------------------------------------------------------------
#
# Type_Income :
#  ['Pensioner' 'Commercial associate' 'Working' 'State servant']
#
# Working                 798
# Commercial associate    365
# Pensioner               269
# State servant           116
# Name: Type_Income, dtype: int64
#
# ----------------------------------------------------------------------
#
# EDUCATION :
#  ['Higher education' 'Secondary / secondary special' 'Lower secondary'
#  'Incomplete higher' 'Academic degree']
#
# Secondary / secondary special    1031
# Higher education                  426
# Incomplete higher                  68
# Lower secondary                    21
# Academic degree                     2
# Name: EDUCATION, dtype: int64
#
# ----------------------------------------------------------------------
#
# Marital_status :
#  ['Married' 'Single / not married' 'Civil marriage' 'Separated' 'Widow']
#
# Married                 1049
# Single / not married     227
# Civil marriage           101
# Separated                 96
# Widow                     75
# Name: Marital_status, dtype: int64
#
# ----------------------------------------------------------------------
#
# Housing_type :
#  ['House / apartment' 'With parents' 'Rented apartment'
#  'Municipal apartment' 'Co-op apartment' 'Office apartment']
#
# House / apartment      1380
# With parents             80
# Municipal apartment      53
# Rented apartment         21
# Office apartment          9
# Co-op apartment           5
# Name: Housing_type, dtype: int64
#
# ----------------------------------------------------------------------
#
# Birthday_count :
#  [-18772. -13557.     nan ... -10229. -15292. -16601.]
#
# -13557.0    5
# -22655.0    5
# -14523.0    5
# -21363.0    5
# -17454.0    4
#            ..
# -11729.0    1
# -15994.0    1
# -13456.0    1
# -19532.0    1
# -16601.0    1
# Name: Birthday_count, Length: 1270, dtype: int64
#
# ----------------------------------------------------------------------
#
# Employed_days :
#  [365243   -586   -678  -1002   -913   -248  -2470  -1644  -4327  -1674
#   -1086   -925   -854   -185  -3350   -691  -4770  -2394   -384  -3647
#   -1546   -808  -1285   -855  -7369  -2269  -4114  -1161  -7288   -166
#    -866   -564  -3366  -2150  -1458  -8369   -508  -1567   -137  -3974
#   -1570  -2878   -140  -2576  -1905  -1724  -1328  -4987  -3496  -1394
#   -1265  -2531  -2105   -860   -217   -535  -6866   -584  -2227  -8161
#    -613   -606  -6944   -346  -1808  -3420   -863  -7413  -7553  -3931
#   -1039   -134   -622  -1595  -1626  -1868   -555  -1935   -931   -900
#   -4305   -499  -2418   -189  -1132  -1770   -919  -1081   -502  -2420
#   -1325  -6367  -2484   -341  -9422  -3054  -2987  -2128   -820   -141
#   -1692  -4686   -693   -567   -885  -2769  -1547  -3179  -5204  -3072
#    -320  -2469   -583   -834  -1085  -1399  -7310  -1748  -2479   -875
#   -2805  -2477  -1477  -1782   -431  -1416   -263  -2349   -412  -7068
#   -1787  -1345  -3717  -1048  -2667  -2606  -2135  -1534  -2311  -1323
#   -5061  -2213  -2152  -4509  -1552  -1569  -1679  -8684  -6337    -97
#   -1222   -531  -7591  -5639  -1776  -5498  -5880   -460  -4532  -3309
#   -3873   -344  -1923   -604  -1922  -1496   -708 -12332  -5209  -6273
#   -2722  -9363   -746  -1322  -3458   -158  -2457  -2811  -7018  -2026
#    -188  -2967  -3166  -5107  -1649  -3694  -3697  -4596  -5674  -1682
#    -196   -530  -1696  -2168 -13382  -1509  -1347  -1405   -227  -9975
#   -1505  -5084  -2905   -356  -1719  -3680   -962  -3000  -4275   -110
#   -2078  -8377  -4392   -126  -7640  -3153   -139  -4023  -4888 -14887
#   -3319  -1966   -200  -6123   -117  -2625  -1763  -3689  -3414  -2910
#   -3412  -1107  -8036  -3608   -101  -3231   -203  -1589  -3577   -735
#   -8737  -1617  -1591   -979   -422   -655  -3653  -1261  -7346  -5545
#   -3810  -1190  -3246  -7676  -1353  -3715  -1113   -992  -2289 -12621
#   -3643   -869  -2174  -5336  -3535  -4407   -453   -960  -4711  -1965
#   -2543  -1393  -2234  -1631  -1619  -5981  -2682  -3443  -2330   -413
#   -6645   -505   -201  -3273  -1462  -2609   -521  -1321  -2467   -716
#   -1632   -614  -1904   -351  -7260   -626  -6853   -458  -1628  -6094
#    -734   -657  -2700   -880   -157   -135  -1497  -1266   -515  -1023
#   -2129   -575  -3262   -430  -2207  -1866  -4568   -309   -578  -6908
#   -1931  -8033  -2257  -3776  -4583  -4404   -727  -3805  -2316  -1455
#   -5422   -581   -893  -1860  -6317  -1000  -4766  -2259  -1344  -4690
#   -8290  -2052  -5004   -923  -1193   -793  -5453    -88  -5495   -593
#   -4816  -1586  -2104  -1032  -9698  -1131  -1175  -8375  -2199  -1912
#    -926  -2499  -2654  -1174   -230  -2276  -2197  -2468 -11448   -932
#   -2956   -619  -3787  -1253  -3242   -298   -124  -4082  -1431  -5330
#   -1017  -1128  -3088  -1466  -1689  -3003  -4039   -588   -282  -4491
#   -1155  -1220  -1203   -712  -2844  -4031  -3322  -6693  -2760  -2532
#   -1646 -11542  -5408  -1374  -3092  -2993  -2379  -1281  -7804  -3002
#    -825  -2057  -1611   -652  -2537  -2331  -4710  -1191  -1162  -3900
#    -219   -223  -3034  -3329   -235  -3503  -1324  -3112  -2959   -234
#    -719  -2616  -4410  -1587  -1537  -1430  -1928  -2753   -867  -2134
#   -3232    -95  -3690  -9870  -4979  -3396   -461  -5206  -3173   -732
#    -432  -2102  -6583   -156  -5460  -2506  -3397  -3792  -3230  -2464
#   -3334  -3110  -2966  -2728  -4161  -7494  -4280  -5891  -1350   -609
#   -2381  -1613  -3533  -6218  -2874  -1654  -2433  -4534   -522   -798
#   -2620   -145   -663  -2299  -1812  -2589   -130  -5056   -796  -7341
#   -1130  -5436  -2368  -1889  -1315  -1678  -2939  -1616  -8405  -3476
#   -3453  -3769  -1359  -2990  -2321  -4267  -1386   -645   -886  -1823
#   -4965  -3716  -1557  -3761  -1981   -102   -288  -2147  -3929   -424
#   -1069  -2323  -3332   -553   -375  -6352  -1056  -1172  -4663  -5587
#   -1406  -8966  -6860  -1463   -561  -3661  -6764 -10600  -3999  -3960
#   -2065  -1205  -1135  -5190  -3720  -2633  -3272  -2500  -6033   -170
#    -278  -3062  -8157  -2653  -1953  -5457  -1997  -3435  -1504  -2696
#  -13735   -132  -6621  -2481  -2818 -11906  -1077  -9258  -2277  -2422
#    -826  -2969  -2086  -1070  -8172   -701  -1384  -9447  -1160  -1952
#   -1354   -469   -563  -1526  -2092  -1749   -168  -4029  -4967  -3282
#    -339  -7979  -9683   -577  -2622   -976  -1994  -1563  -4523   -340
#   -6614  -1639  -3392  -3261  -3928  -5082  -3630  -3591  -1199  -4304
#   -2514  -2187  -7140    -96  -5176  -6761  -2356  -2908  -3333  -3596
#   -4606  -4030  -5246  -2906  -1915  -1267  -1256  -1721  -2317  -1518
#    -864  -7364  -1101  -2231  -1327   -355  -1934  -5179  -2326   -980
#   -1224  -7048  -2266    -73  -2661   -286  -8044   -523   -978   -795
#   -2351  -1114  -3760  -5145  -4119  -3641   -481  -4603   -888   -393
#   -1007 -10688  -2228  -8479  -2180  -1362  -1876  -2265 -11389  -4146
#   -5500  -5521   -658  -3695   -901  -1751  -3663  -3149  -1375   -183
#    -500   -489  -2450  -1539  -1556  -7095   -674  -2605  -1999  -4599
#   -6488  -1054   -745  -3505  -1585  -6904  -2530  -1420   -314  -2441
#  -11884  -4520  -3289  -1495  -3504  -3093  -2417  -2554   -818  -9359
#   -1508 -10364  -4331  -2296  -2142  -3163  -3961  -2896  -1185  -1670
#   -3670  -1202  -4936   -596  -6648   -747  -1741  -1615  -1444  -2089
#    -397  -2592  -1618  -2822  -1600  -2558   -991  -2758  -2988  -2904
#   -3377  -3902  -3202   -671   -848   -552  -2559  -2361  -3854  -1182
#   -2384  -8230  -2493  -2362  -4034  -2143  -2393  -2565   -450  -5496
#   -2319   -191  -3506  -2865  -2339  -2072  -7013  -3008  -2932   -565
#   -1282  -3154  -1225  -2333  -1869 -11940  -3515  -3291   -407   -444
#    -226   -279  -1661   -896   -670  -2533  -7400  -3339  -1259   -265
#   -1870  -2540  -2978   -187   -477  -1436  -1978  -1133  -2985 -10758
#   -4288    -89  -6930  -1807  -3143  -3850  -4560   -785  -3570   -777
#  -11451   -742  -5950   -464   -385  -2475  -2051  -3607  -2454  -7614
#   -2796   -642  -4004  -4917  -5622   -313  -1753  -5830  -1677  -3078
#   -3061   -625  -1381   -308  -5437   -218  -3195  -1198  -1473  -5483
#    -704 -12870  -5373  -7128  -2255  -5345  -3574   -164  -6226  -6678
#   -2024   -890  -6075  -1774   -686  -3229  -3455  -5454 -13010  -5507
#   -6640  -5488   -221   -127  -8760  -7718  -3123  -1652  -6879  -2673
#    -420  -1072  -5760  -1871  -1707  -1962  -1598  -1583  -7264   -536
#   -1313  -2512  -5673  -3380  -3944  -3654   -171  -1801  -1138  -1897
#   -2980  -1581  -6558  -4434   -210  -3032  -2389  -1467   -377 -10762
#   -2788  -3668  -2340  -9925   -918  -4219   -194  -3010   -370   -232
#    -285  -1830  -3853  -2866  -1022  -2423  -2545  -6230   -104  -2631
#    -367   -857  -4887   -433   -803  -3361  -1520  -5155  -5006  -2191
#   -1064   -828  -4874  -1217  -7557  -5334   -611  -5215   -438   -958
#   -3095  -2827  -3693  -2262   -195   -109  -5862  -1200  -1891  -4662
#   -2924  -1648  -3536  -2182  -1209  -2859]
#
#  365243    261
# -586         6
# -622         5
# -460         5
# -1678        5
#           ...
# -3034        1
# -1324        1
# -3112        1
# -2959        1
# -2859        1
# Name: Employed_days, Length: 956, dtype: int64
#
# ----------------------------------------------------------------------
#
# Mobile_phone :
#  [1]
#
# 1    1548
# Name: Mobile_phone, dtype: int64
#
# ----------------------------------------------------------------------
#
# Work_Phone :
#  [0 1]
#
# 0    1226
# 1     322
# Name: Work_Phone, dtype: int64
#
# ----------------------------------------------------------------------
#
# Phone :
#  [0 1]
#
# 0    1069
# 1     479
# Name: Phone, dtype: int64
#
# ----------------------------------------------------------------------
#
# EMAIL_ID :
#  [0 1]
#
# 0    1405
# 1     143
# Name: EMAIL_ID, dtype: int64
#
# ----------------------------------------------------------------------
#
# Type_Occupation :
#  [nan 'Core staff' 'Cooking staff' 'Laborers' 'Sales staff' 'Accountants'
#  'High skill tech staff' 'Managers' 'Cleaning staff' 'Drivers'
#  'Low-skill Laborers' 'IT staff' 'Waiters/barmen staff' 'Security staff'
#  'Medicine staff' 'Private service staff' 'HR staff' 'Secretaries'
#  'Realty agents']
#
# Laborers                 268
# Core staff               174
# Managers                 136
# Sales staff              122
# Drivers                   86
# High skill tech staff     65
# Medicine staff            50
# Accountants               44
# Security staff            25
# Cleaning staff            22
# Cooking staff             21
# Private service staff     17
# Secretaries                9
# Low-skill Laborers         9
# Waiters/barmen staff       5
# HR staff                   3
# IT staff                   2
# Realty agents              2
# Name: Type_Occupation, dtype: int64
#
# ----------------------------------------------------------------------
#
# Family_Members :
#  [ 2  3  1  4  6  5 15]
#
# 2     802
# 1     334
# 3     268
# 4     127
# 5      15
# 6       1
# 15      1
# Name: Family_Members, dtype: int64
#
# ----------------------------------------------------------------------
#
# label :
#  [1 0]
#
# 0    1373
# 1     175
# Name: label, dtype: int64
#
# ----------------------------------------------------------------------

# %% [markdown]
# ## Null Value Count

# %%
df.isnull().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
df.isnull().mean()*100 ## converting to percentage
# Out:
# Ind_ID              0.000000
# GENDER              0.452196
# Car_Owner           0.000000
# Propert_Owner       0.000000
# CHILDREN            0.000000
# Annual_income       1.485788
# Type_Income         0.000000
# EDUCATION           0.000000
# Marital_status      0.000000
# Housing_type        0.000000
# Birthday_count      1.421189
# Employed_days       0.000000
# Mobile_phone        0.000000
# Work_Phone          0.000000
# Phone               0.000000
# EMAIL_ID            0.000000
# Type_Occupation    31.524548
# Family_Members      0.000000
# label               0.000000
# dtype: float64

# %% [markdown]
# ## Observations
#
# 1. There are total 1548 rows × 19 columns
# 2. Columns Names are need to change for better understanding.
# 3. GENDER, Annual_income, Birthday_count, Type_Occupation Have Null Values
# 4. Type_Occupation Have more than 30% Null Value so it is good to drop that column
# 5. Employed_days & Birthday_count Have -ve values, as those are days so for better calculation we will convert in years
# 6. Mobile_phone have only one unique value so we will drop that column

# %% [markdown]
# # Basic Cleanning

# %% [markdown]
# ## Droping Unnecessary Columns

# %%
# As Mobile_phone have singel value & Type_Occupation have to much null value
# We will drop 'Mobile_phone' & 'Type_Occupation'
df1 = df.drop(['Mobile_phone', 'Type_Occupation'], axis=1)

# %% [markdown]
# ## Droping Duplicate Rows

# %%
df1.drop_duplicates()
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# 1     Commercial associate               Higher education
# 2     Commercial associate               Higher education
# 3     Commercial associate               Higher education
# 4     Commercial associate               Higher education
# ...                    ...                            ...
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type  Birthday_count  Employed_days  \
# 0                  Married  House / apartment        -18772.0         365243
# 1                  Married  House / apartment        -13557.0           -586
# 2                  Married  House / apartment             NaN           -586
# 3                  Married  House / apartment        -13557.0           -586
# 4                  Married  House / apartment        -13557.0           -586
# ...                    ...                ...             ...            ...
# 1543               Married  House / apartment        -11957.0          -2182
# 1544  Single / not married  House / apartment        -10229.0          -1209
# 1545               Married  House / apartment        -13174.0          -2477
# 1546        Civil marriage  House / apartment        -15292.0           -645
# 1547               Married  House / apartment        -16601.0          -2859
#
#       Work_Phone  Phone  EMAIL_ID  Family_Members  label
# 0              0      0         0               2      1
# 1              1      1         0               2      1
# 2              1      1         0               2      1
# 3              1      1         0               2      1
# 4              1      1         0               2      1
# ...          ...    ...       ...             ...    ...
# 1543           0      0         0               2      0
# 1544           0      0         0               1      0
# 1545           0      0         0               4      0
# 1546           1      1         0               2      0
# 1547           0      0         0               2      0
#
# [1548 rows x 17 columns]

# %% [markdown]
# ## Converting Days to Years

# %% [markdown]
# ### Column Birthday_count

# %%
# Column Birthday_count is in days so for better understanding we will convert it in to years as age
df1['Birthday_count'] = round(df1['Birthday_count']/-365,0)

#round function used to round the result of the calculation to a whole number.
# 0 is used to round to zero decimal places.

# %% [markdown]
# ### Column Employed_days

# %%
# As mentioned in document, if 'Employed_days' is positive, it means person currently unemployed.
# Hence Checking unique values greater than 0
df1[df1['Employed_days']>0]['Employed_days'].unique()
# Out:
# array([365243])

# %%
# As from above 365243 is unique value which is greater than 0, hence replacing it with 0
df1['Employed_days'].replace(365243, 0, inplace=True)

# %%
# Converting 'Employed_days' values from Day to Years
df1['Employed_days'] = abs(round(df1['Employed_days']/-365,0))
## () abs functions ensure that the result of the calculation is positive, even if the original values were negative.

# %% [markdown]
# ## Renaming Column

# %%
# Making Copy Before proceding
df2 = df1.copy()

# %%
df2.rename(columns={'Ind_ID':'id', 'GENDER':'gender', 'Car_Owner':'car', 'Propert_Owner':'property', 'CHILDREN':'children',
                          'Annual_income':'income', 'Type_Income':'income_type', 'EDUCATION':'education', 'Marital_status':'marital_status',
                          'Housing_type':'housing_type', 'Birthday_count':'age', 'Employed_days':'employed_years',
                          'Work_Phone':'work_phone', 'Phone':'phone', 'EMAIL_ID':'email',
                          'Family_Members':'family_members'},
                        inplace = True)

# %%
df2
# Out:
#            id gender car property  children    income           income_type  \
# 0     5008827      M   Y        Y         0  180000.0             Pensioner
# 1     5009744      F   Y        N         0  315000.0  Commercial associate
# 2     5009746      F   Y        N         0  315000.0  Commercial associate
# 3     5009749      F   Y        N         0       NaN  Commercial associate
# 4     5009752      F   Y        N         0  315000.0  Commercial associate
# ...       ...    ...  ..      ...       ...       ...                   ...
# 1543  5028645      F   N        Y         0       NaN  Commercial associate
# 1544  5023655      F   N        N         0  225000.0  Commercial associate
# 1545  5115992      M   Y        Y         2  180000.0               Working
# 1546  5118219      M   Y        N         0  270000.0               Working
# 1547  5053790      F   Y        Y         0  225000.0               Working
#
#                           education        marital_status       housing_type  \
# 0                  Higher education               Married  House / apartment
# 1                  Higher education               Married  House / apartment
# 2                  Higher education               Married  House / apartment
# 3                  Higher education               Married  House / apartment
# 4                  Higher education               Married  House / apartment
# ...                             ...                   ...                ...
# 1543               Higher education               Married  House / apartment
# 1544              Incomplete higher  Single / not married  House / apartment
# 1545               Higher education               Married  House / apartment
# 1546  Secondary / secondary special        Civil marriage  House / apartment
# 1547               Higher education               Married  House / apartment
#
#        age  employed_years  work_phone  phone  email  family_members  label
# 0     51.0             0.0           0      0      0               2      1
# 1     37.0             2.0           1      1      0               2      1
# 2      NaN             2.0           1      1      0               2      1
# 3     37.0             2.0           1      1      0               2      1
# 4     37.0             2.0           1      1      0               2      1
# ...    ...             ...         ...    ...    ...             ...    ...
# 1543  33.0             6.0           0      0      0               2      0
# 1544  28.0             3.0           0      0      0               1      0
# 1545  36.0             7.0           0      0      0               4      0
# 1546  42.0             2.0           1      1      0               2      0
# 1547  45.0             8.0           0      0      0               2      0
#
# [1548 rows x 17 columns]

# %% [markdown]
# # Dealing With Missing Value

# %% [markdown]
# ## Null Count & Percentage

# %%
df2.isnull().sum()
# Out:
# id                 0
# gender             7
# car                0
# property           0
# children           0
# income            23
# income_type        0
# education          0
# marital_status     0
# housing_type       0
# age               22
# employed_years     0
# work_phone         0
# phone              0
# email              0
# family_members     0
# label              0
# dtype: int64

# %%
(df2.isnull().sum()/len(df2))*100 ## converting in percentage
# Out:
# id                0.000000
# gender            0.452196
# car               0.000000
# property          0.000000
# children          0.000000
# income            1.485788
# income_type       0.000000
# education         0.000000
# marital_status    0.000000
# housing_type      0.000000
# age               1.421189
# employed_years    0.000000
# work_phone        0.000000
# phone             0.000000
# email             0.000000
# family_members    0.000000
# label             0.000000
# dtype: float64

# %% [markdown]
# ## Missing Value Plot

# %%
msno.bar(df2)
# Out:
# <Axes: >

# %%
msno.matrix(df2)
# Out:
# <Axes: >

# %% [markdown]
# ## Droping of Null Value

# %%
df3 = df2.copy()

# %%
df3.isnull().sum().sum()
# Out:
# 52

# %%
(df3.isnull().mean()*100).sum()   ## % of null value
# Out:
# 3.359173126614987

# %%
# As we can see very few values are null i.e around 3% so we can delete it
df3 = df3.dropna()

# %%
df3
# Out:
#            id gender car property  children    income           income_type  \
# 0     5008827      M   Y        Y         0  180000.0             Pensioner
# 1     5009744      F   Y        N         0  315000.0  Commercial associate
# 4     5009752      F   Y        N         0  315000.0  Commercial associate
# 6     5009754      F   Y        N         0  315000.0  Commercial associate
# 7     5009894      F   N        N         0  180000.0             Pensioner
# ...       ...    ...  ..      ...       ...       ...                   ...
# 1542  5118268      M   Y        N         1  360000.0         State servant
# 1544  5023655      F   N        N         0  225000.0  Commercial associate
# 1545  5115992      M   Y        Y         2  180000.0               Working
# 1546  5118219      M   Y        N         0  270000.0               Working
# 1547  5053790      F   Y        Y         0  225000.0               Working
#
#                           education        marital_status       housing_type  \
# 0                  Higher education               Married  House / apartment
# 1                  Higher education               Married  House / apartment
# 4                  Higher education               Married  House / apartment
# 6                  Higher education               Married  House / apartment
# 7     Secondary / secondary special               Married  House / apartment
# ...                             ...                   ...                ...
# 1542  Secondary / secondary special               Married  House / apartment
# 1544              Incomplete higher  Single / not married  House / apartment
# 1545               Higher education               Married  House / apartment
# 1546  Secondary / secondary special        Civil marriage  House / apartment
# 1547               Higher education               Married  House / apartment
#
#        age  employed_years  work_phone  phone  email  family_members  label
# 0     51.0             0.0           0      0      0               2      1
# 1     37.0             2.0           1      1      0               2      1
# 4     37.0             2.0           1      1      0               2      1
# 6     37.0             2.0           1      1      0               2      1
# 7     61.0             0.0           0      0      0               2      1
# ...    ...             ...         ...    ...    ...             ...    ...
# 1542  31.0            10.0           0      1      0               3      0
# 1544  28.0             3.0           0      0      0               1      0
# 1545  36.0             7.0           0      0      0               4      0
# 1546  42.0             2.0           1      1      0               2      0
# 1547  45.0             8.0           0      0      0               2      0
#
# [1496 rows x 17 columns]

# %% [markdown]
# # Dateset For SQL or PyMySQL

# %% [markdown]
# ## Prepairing Dataset for SQL

# %%
df4 = df3.copy()

# %%
df4 = df4.reset_index()
df4 = df4.drop('index', axis=1)

# %%
df4     # This is final dataset for PyMySQL
# Out:
#            id gender car property  children    income           income_type  \
# 0     5008827      M   Y        Y         0  180000.0             Pensioner
# 1     5009744      F   Y        N         0  315000.0  Commercial associate
# 2     5009752      F   Y        N         0  315000.0  Commercial associate
# 3     5009754      F   Y        N         0  315000.0  Commercial associate
# 4     5009894      F   N        N         0  180000.0             Pensioner
# ...       ...    ...  ..      ...       ...       ...                   ...
# 1491  5118268      M   Y        N         1  360000.0         State servant
# 1492  5023655      F   N        N         0  225000.0  Commercial associate
# 1493  5115992      M   Y        Y         2  180000.0               Working
# 1494  5118219      M   Y        N         0  270000.0               Working
# 1495  5053790      F   Y        Y         0  225000.0               Working
#
#                           education        marital_status       housing_type  \
# 0                  Higher education               Married  House / apartment
# 1                  Higher education               Married  House / apartment
# 2                  Higher education               Married  House / apartment
# 3                  Higher education               Married  House / apartment
# 4     Secondary / secondary special               Married  House / apartment
# ...                             ...                   ...                ...
# 1491  Secondary / secondary special               Married  House / apartment
# 1492              Incomplete higher  Single / not married  House / apartment
# 1493               Higher education               Married  House / apartment
# 1494  Secondary / secondary special        Civil marriage  House / apartment
# 1495               Higher education               Married  House / apartment
#
#        age  employed_years  work_phone  phone  email  family_members  label
# 0     51.0             0.0           0      0      0               2      1
# 1     37.0             2.0           1      1      0               2      1
# 2     37.0             2.0           1      1      0               2      1
# 3     37.0             2.0           1      1      0               2      1
# 4     61.0             0.0           0      0      0               2      1
# ...    ...             ...         ...    ...    ...             ...    ...
# 1491  31.0            10.0           0      1      0               3      0
# 1492  28.0             3.0           0      0      0               1      0
# 1493  36.0             7.0           0      0      0               4      0
# 1494  42.0             2.0           1      1      0               2      0
# 1495  45.0             8.0           0      0      0               2      0
#
# [1496 rows x 17 columns]

# %%
## df4.to_csv('details.csv', index_label='index') to convert in csv and download

# %% [markdown]
# # Dealing With Outlier

# %% [markdown]
# ## Droping id Column & Duplicates After Removal of id Column

# %%
df5 = df4.drop(['id'], axis=1)

# %%
df5 = df5.drop_duplicates()

# %%
df5
# Out:
#      gender car property  children    income           income_type  \
# 0         M   Y        Y         0  180000.0             Pensioner
# 1         F   Y        N         0  315000.0  Commercial associate
# 4         F   N        N         0  180000.0             Pensioner
# 5         M   Y        Y         1  450000.0  Commercial associate
# 6         M   Y        Y         1  450000.0             Pensioner
# ...     ...  ..      ...       ...       ...                   ...
# 1490      F   Y        Y         1  144000.0               Working
# 1491      M   Y        N         1  360000.0         State servant
# 1492      F   N        N         0  225000.0  Commercial associate
# 1494      M   Y        N         0  270000.0               Working
# 1495      F   Y        Y         0  225000.0               Working
#
#                           education        marital_status       housing_type  \
# 0                  Higher education               Married  House / apartment
# 1                  Higher education               Married  House / apartment
# 4     Secondary / secondary special               Married  House / apartment
# 5     Secondary / secondary special               Married  House / apartment
# 6     Secondary / secondary special               Married  House / apartment
# ...                             ...                   ...                ...
# 1490               Higher education               Married  House / apartment
# 1491  Secondary / secondary special               Married  House / apartment
# 1492              Incomplete higher  Single / not married  House / apartment
# 1494  Secondary / secondary special        Civil marriage  House / apartment
# 1495               Higher education               Married  House / apartment
#
#        age  employed_years  work_phone  phone  email  family_members  label
# 0     51.0             0.0           0      0      0               2      1
# 1     37.0             2.0           1      1      0               2      1
# 4     61.0             0.0           0      0      0               2      1
# 5     50.0             2.0           0      1      1               3      1
# 6     50.0             2.0           0      1      1               3      1
# ...    ...             ...         ...    ...    ...             ...    ...
# 1490  35.0             8.0           0      0      0               3      0
# 1491  31.0            10.0           0      1      0               3      0
# 1492  28.0             3.0           0      0      0               1      0
# 1494  42.0             2.0           1      1      0               2      0
# 1495  45.0             8.0           0      0      0               2      0
#
# [1330 rows x 16 columns]

# %% [markdown]
# ## Analysing Outlier With Plots

# %% [markdown]
# ### Boxplot to see outliers

# %%
# Box Plot to see outlier
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

fig.suptitle('Boxplot to See Outlier')

sns.boxplot(ax=axes[0, 0], data=df5, x='children')
sns.boxplot(ax=axes[0, 1], data=df5, x='family_members')
sns.boxplot(ax=axes[0, 2], data=df5, x='age')
sns.boxplot(ax=axes[1, 0], data=df5, x='employed_years')
sns.boxplot(ax=axes[1, 1], data=df5, x='income')
plt.show()

# %% [markdown]
# ### Histogram Plot

# %%
# Histogram Plot to see outlier

fig, axes = plt.subplots(2, 3, figsize=(18, 8))

fig.suptitle('histogram to See Outlier')

sns.histplot(ax=axes[0, 0], data=df5, x='children', kde=True)
sns.histplot(ax=axes[0, 1], data=df5, x='family_members', kde=True)
sns.histplot(ax=axes[0, 2], data=df5, x='age', kde=True)
sns.histplot(ax=axes[1, 0], data=df5, x='employed_years', kde=True)
sns.histplot(ax=axes[1, 1], data=df5, x='income', kde=True)
plt.show()

# %% [markdown]
# ## Observation
#
# 1. From the above Graphs it is Observe that 'children', 'family_members', 'employed_years' and 'income' have OUtliers

# %% [markdown]
# ## Removing Children Outlier

# %%
high_children = round(df5['children'].quantile(0.999),0)
print('high_children :', high_children)
low_children = df5['children'].quantile(0.001)
print('low_children :', low_children)
# Out:
# high_children : 4.0
# low_children : 0.0

# %%
df5 = df5[(df5['children']>=low_children) & (df5['children']<=high_children)]

# %% [markdown]
# ## Removing Income Outlier

# %%
high_income = df5['income'].quantile(0.999)
print('high_income :', high_income)
low_income = df5['income'].quantile(0.001)
print('low_income :', low_income)
# Out:
# high_income : 900000.0
# low_income : 36590.4

# %%
df5 = df5[(df5['income']>=low_income) & (df5['income']<=high_income)]

# %% [markdown]
# ## Removing employed_years Outlier

# %%
high_years = round(df5['employed_years'].quantile(0.999),0)
print('high_years :', high_years)
low_years = df5['employed_years'].quantile(0.001)
print('low_years :', low_years)
# Out:
# high_years : 38.0
# low_years : 0.0

# %%
df5 = df5[(df5['employed_years']>=low_years) & (df5['employed_years']<=high_years)]

# %%
high_members = round(df5['family_members'].quantile(0.999),0)
print('high_members :', high_members)
low_members = df5['family_members'].quantile(0.001)
print('low_members :', low_members)
# Out:
# high_members : 5.0
# low_members : 1.0

# %%
df5
# Out:
#      gender car property  children    income           income_type  \
# 0         M   Y        Y         0  180000.0             Pensioner
# 1         F   Y        N         0  315000.0  Commercial associate
# 4         F   N        N         0  180000.0             Pensioner
# 5         M   Y        Y         1  450000.0  Commercial associate
# 6         M   Y        Y         1  450000.0             Pensioner
# ...     ...  ..      ...       ...       ...                   ...
# 1490      F   Y        Y         1  144000.0               Working
# 1491      M   Y        N         1  360000.0         State servant
# 1492      F   N        N         0  225000.0  Commercial associate
# 1494      M   Y        N         0  270000.0               Working
# 1495      F   Y        Y         0  225000.0               Working
#
#                           education        marital_status       housing_type  \
# 0                  Higher education               Married  House / apartment
# 1                  Higher education               Married  House / apartment
# 4     Secondary / secondary special               Married  House / apartment
# 5     Secondary / secondary special               Married  House / apartment
# 6     Secondary / secondary special               Married  House / apartment
# ...                             ...                   ...                ...
# 1490               Higher education               Married  House / apartment
# 1491  Secondary / secondary special               Married  House / apartment
# 1492              Incomplete higher  Single / not married  House / apartment
# 1494  Secondary / secondary special        Civil marriage  House / apartment
# 1495               Higher education               Married  House / apartment
#
#        age  employed_years  work_phone  phone  email  family_members  label
# 0     51.0             0.0           0      0      0               2      1
# 1     37.0             2.0           1      1      0               2      1
# 4     61.0             0.0           0      0      0               2      1
# 5     50.0             2.0           0      1      1               3      1
# 6     50.0             2.0           0      1      1               3      1
# ...    ...             ...         ...    ...    ...             ...    ...
# 1490  35.0             8.0           0      0      0               3      0
# 1491  31.0            10.0           0      1      0               3      0
# 1492  28.0             3.0           0      0      0               1      0
# 1494  42.0             2.0           1      1      0               2      0
# 1495  45.0             8.0           0      0      0               2      0
#
# [1329 rows x 16 columns]

# %% [markdown]
# # Final Dataset For DA & ML

# %%
final = df5.copy()

# %%
final
# Out:
#      gender car property  children    income           income_type  \
# 0         M   Y        Y         0  180000.0             Pensioner
# 1         F   Y        N         0  315000.0  Commercial associate
# 4         F   N        N         0  180000.0             Pensioner
# 5         M   Y        Y         1  450000.0  Commercial associate
# 6         M   Y        Y         1  450000.0             Pensioner
# ...     ...  ..      ...       ...       ...                   ...
# 1490      F   Y        Y         1  144000.0               Working
# 1491      M   Y        N         1  360000.0         State servant
# 1492      F   N        N         0  225000.0  Commercial associate
# 1494      M   Y        N         0  270000.0               Working
# 1495      F   Y        Y         0  225000.0               Working
#
#                           education        marital_status       housing_type  \
# 0                  Higher education               Married  House / apartment
# 1                  Higher education               Married  House / apartment
# 4     Secondary / secondary special               Married  House / apartment
# 5     Secondary / secondary special               Married  House / apartment
# 6     Secondary / secondary special               Married  House / apartment
# ...                             ...                   ...                ...
# 1490               Higher education               Married  House / apartment
# 1491  Secondary / secondary special               Married  House / apartment
# 1492              Incomplete higher  Single / not married  House / apartment
# 1494  Secondary / secondary special        Civil marriage  House / apartment
# 1495               Higher education               Married  House / apartment
#
#        age  employed_years  work_phone  phone  email  family_members  label
# 0     51.0             0.0           0      0      0               2      1
# 1     37.0             2.0           1      1      0               2      1
# 4     61.0             0.0           0      0      0               2      1
# 5     50.0             2.0           0      1      1               3      1
# 6     50.0             2.0           0      1      1               3      1
# ...    ...             ...         ...    ...    ...             ...    ...
# 1490  35.0             8.0           0      0      0               3      0
# 1491  31.0            10.0           0      1      0               3      0
# 1492  28.0             3.0           0      0      0               1      0
# 1494  42.0             2.0           1      1      0               2      0
# 1495  45.0             8.0           0      0      0               2      0
#
# [1329 rows x 16 columns]

# %% [markdown]
# # Data Analysis Using Visualization

# %% [markdown]
# ## Basic Exploration

# %%
final = final.reset_index()
final = final.drop('index', axis=1)
final
# Out:
#      gender car property  children    income           income_type  \
# 0         M   Y        Y         0  180000.0             Pensioner
# 1         F   Y        N         0  315000.0  Commercial associate
# 2         F   N        N         0  180000.0             Pensioner
# 3         M   Y        Y         1  450000.0  Commercial associate
# 4         M   Y        Y         1  450000.0             Pensioner
# ...     ...  ..      ...       ...       ...                   ...
# 1324      F   Y        Y         1  144000.0               Working
# 1325      M   Y        N         1  360000.0         State servant
# 1326      F   N        N         0  225000.0  Commercial associate
# 1327      M   Y        N         0  270000.0               Working
# 1328      F   Y        Y         0  225000.0               Working
#
#                           education        marital_status       housing_type  \
# 0                  Higher education               Married  House / apartment
# 1                  Higher education               Married  House / apartment
# 2     Secondary / secondary special               Married  House / apartment
# 3     Secondary / secondary special               Married  House / apartment
# 4     Secondary / secondary special               Married  House / apartment
# ...                             ...                   ...                ...
# 1324               Higher education               Married  House / apartment
# 1325  Secondary / secondary special               Married  House / apartment
# 1326              Incomplete higher  Single / not married  House / apartment
# 1327  Secondary / secondary special        Civil marriage  House / apartment
# 1328               Higher education               Married  House / apartment
#
#        age  employed_years  work_phone  phone  email  family_members  label
# 0     51.0             0.0           0      0      0               2      1
# 1     37.0             2.0           1      1      0               2      1
# 2     61.0             0.0           0      0      0               2      1
# 3     50.0             2.0           0      1      1               3      1
# 4     50.0             2.0           0      1      1               3      1
# ...    ...             ...         ...    ...    ...             ...    ...
# 1324  35.0             8.0           0      0      0               3      0
# 1325  31.0            10.0           0      1      0               3      0
# 1326  28.0             3.0           0      0      0               1      0
# 1327  42.0             2.0           1      1      0               2      0
# 1328  45.0             8.0           0      0      0               2      0
#
# [1329 rows x 16 columns]

# %%
final.describe(include='all').T
# Out:
#                  count unique                            top  freq  \
# gender            1329      2                              F   843
# car               1329      2                              N   804
# property          1329      2                              Y   864
# children        1329.0    NaN                            NaN   NaN
# income          1329.0    NaN                            NaN   NaN
# income_type       1329      4                        Working   680
# education         1329      5  Secondary / secondary special   893
# marital_status    1329      5                        Married   899
# housing_type      1329      6              House / apartment  1179
# age             1329.0    NaN                            NaN   NaN
# employed_years  1329.0    NaN                            NaN   NaN
# work_phone      1329.0    NaN                            NaN   NaN
# phone           1329.0    NaN                            NaN   NaN
# email           1329.0    NaN                            NaN   NaN
# family_members  1329.0    NaN                            NaN   NaN
# label           1329.0    NaN                            NaN   NaN
#
#                          mean            std      min       25%       50%  \
# gender                    NaN            NaN      NaN       NaN       NaN
# car                       NaN            NaN      NaN       NaN       NaN
# property                  NaN            NaN      NaN       NaN       NaN
# children             0.419112        0.70687      0.0       0.0       0.0
# income          188870.671558  106793.028277  33750.0  121500.0  162000.0
# income_type               NaN            NaN      NaN       NaN       NaN
# education                 NaN            NaN      NaN       NaN       NaN
# marital_status            NaN            NaN      NaN       NaN       NaN
# housing_type              NaN            NaN      NaN       NaN       NaN
# age                 43.865312      11.526648     21.0      34.0      43.0
# employed_years       6.068473       6.587271      0.0       1.0       4.0
# work_phone            0.20316       0.402502      0.0       0.0       0.0
# phone                0.306245       0.461106      0.0       0.0       0.0
# email                0.097065       0.296158      0.0       0.0       0.0
# family_members        2.17231       0.899942      1.0       2.0       2.0
# label                0.091798        0.28885      0.0       0.0       0.0
#
#                      75%        max
# gender               NaN        NaN
# car                  NaN        NaN
# property             NaN        NaN
# children             1.0        4.0
# income          225000.0  1575000.0
# income_type          NaN        NaN
# education            NaN        NaN
# marital_status       NaN        NaN
# housing_type         NaN        NaN
# age                 53.0       68.0
# employed_years       9.0       41.0
# work_phone           0.0        1.0
# phone                1.0        1.0
# email                0.0        1.0
# family_members       3.0        6.0
# label                0.0        1.0

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1329 entries, 0 to 1328
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          1329 non-null   object
#  1   car             1329 non-null   object
#  2   property        1329 non-null   object
#  3   children        1329 non-null   int64
#  4   income          1329 non-null   float64
#  5   income_type     1329 non-null   object
#  6   education       1329 non-null   object
#  7   marital_status  1329 non-null   object
#  8   housing_type    1329 non-null   object
#  9   age             1329 non-null   float64
#  10  employed_years  1329 non-null   float64
#  11  work_phone      1329 non-null   int64
#  12  phone           1329 non-null   int64
#  13  email           1329 non-null   int64
#  14  family_members  1329 non-null   int64
#  15  label           1329 non-null   int64
# dtypes: float64(3), int64(6), object(7)
# memory usage: 166.2+ KB

# %% [markdown]
# ## Co-Relation With label

# %%
plt.figure(figsize = (8,8))
sns.heatmap(final.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Gender Wise Analysis

# %%
plt.figure(1, figsize=(12, 12)).add_subplot(121)
plt.pie(final['gender'].value_counts(), labels=['Female', 'Male'], autopct='%1.2f%%')
plt.title('Applications Submitted Based on Gender')


plt.figure(1, figsize=(12, 12)).add_subplot(122)
plt.pie(final[final['label']==0]['gender'].value_counts(), labels=['Female', 'Male'], autopct='%1.2f%%')
plt.title('Applications Approved Based on Gender')


plt.show()

print(
'These plots shows that,\n\n'
'''Majority of application which are approved are submitted by females''')
# Out:
# These plots shows that,
#
# Majority of application which are approved are submitted by females

# %% [markdown]
# ## Car & Property Analysis

# %%
plt.figure(1, figsize=(12, 12)).add_subplot(121)
plt.pie(final['car'].value_counts(), labels=['No', 'Yes'], autopct='%1.2f%%')
plt.title('Applications Submitted Based on Owning a Car')


plt.figure(1, figsize=(12, 12)).add_subplot(122)
plt.pie(final['property'].value_counts(), labels=['Yes','No'], autopct='%1.2f%%')
plt.title('Applications Submitted Based On Owning a Property')


plt.show()

print(
'These plots shows that,\n\n'
'''Majority of Applicatant's owns a property in place of Car
''')
# Out:
# These plots shows that,
#
# Majority of Applicatant's owns a property in place of Car

# %% [markdown]
# ## Children & Family Members

# %%
plt.figure(1, figsize=(15, 5)).add_subplot(121)
sns.barplot(x=final['children'].value_counts().index, y=final['children'].value_counts().values)
plt.xlabel('No of Children'); plt.ylabel('Children Count'); plt.title('Children Count')

plt.figure(1, figsize=(15, 5)).add_subplot(122)
sns.barplot(x=final['family_members'].value_counts().index, y=final['family_members'].value_counts().values)
plt.xlabel('No of Family Members'); plt.ylabel('Family Members Count'); plt.title('Family Members Count')

plt.show()

print(
'These plots shows that,\n\n'

'''Majority of Applicatant's Family Size is 2 and they don't have any children
''')
# Out:
# These plots shows that,
#
# Majority of Applicatant's Family Size is 2 and they don't have any children

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Categorical Features Encoding

# %%
final_ml = final.copy()
final_ml
# Out:
#      gender car property  children    income           income_type  \
# 0         M   Y        Y         0  180000.0             Pensioner
# 1         F   Y        N         0  315000.0  Commercial associate
# 2         F   N        N         0  180000.0             Pensioner
# 3         M   Y        Y         1  450000.0  Commercial associate
# 4         M   Y        Y         1  450000.0             Pensioner
# ...     ...  ..      ...       ...       ...                   ...
# 1324      F   Y        Y         1  144000.0               Working
# 1325      M   Y        N         1  360000.0         State servant
# 1326      F   N        N         0  225000.0  Commercial associate
# 1327      M   Y        N         0  270000.0               Working
# 1328      F   Y        Y         0  225000.0               Working
#
#                           education        marital_status       housing_type  \
# 0                  Higher education               Married  House / apartment
# 1                  Higher education               Married  House / apartment
# 2     Secondary / secondary special               Married  House / apartment
# 3     Secondary / secondary special               Married  House / apartment
# 4     Secondary / secondary special               Married  House / apartment
# ...                             ...                   ...                ...
# 1324               Higher education               Married  House / apartment
# 1325  Secondary / secondary special               Married  House / apartment
# 1326              Incomplete higher  Single / not married  House / apartment
# 1327  Secondary / secondary special        Civil marriage  House / apartment
# 1328               Higher education               Married  House / apartment
#
#        age  employed_years  work_phone  phone  email  family_members  label
# 0     51.0             0.0           0      0      0               2      1
# 1     37.0             2.0           1      1      0               2      1
# 2     61.0             0.0           0      0      0               2      1
# 3     50.0             2.0           0      1      1               3      1
# 4     50.0             2.0           0      1      1               3      1
# ...    ...             ...         ...    ...    ...             ...    ...
# 1324  35.0             8.0           0      0      0               3      0
# 1325  31.0            10.0           0      1      0               3      0
# 1326  28.0             3.0           0      0      0               1      0
# 1327  42.0             2.0           1      1      0               2      0
# 1328  45.0             8.0           0      0      0               2      0
#
# [1329 rows x 16 columns]

# %%
Categorical_Features = final_ml.columns[(final_ml.dtypes =='object').values].tolist()  ##tolist(): This converts the selected column names into a Python list
Categorical_Features
# Out:
# ['gender',
#  'car',
#  'property',
#  'income_type',
#  'education',
#  'marital_status',
#  'housing_type']

# %%
for i in Categorical_Features:
        globals()['LE_{}'.format(i)] = LabelEncoder()
        final_ml[i] = globals()['LE_{}'.format(i)].fit_transform(final_ml[i])
final_ml
# Out:
#       gender  car  property  children    income  income_type  education  \
# 0          1    1         1         0  180000.0            1          1
# 1          0    1         0         0  315000.0            0          1
# 2          0    0         0         0  180000.0            1          4
# 3          1    1         1         1  450000.0            0          4
# 4          1    1         1         1  450000.0            1          4
# ...      ...  ...       ...       ...       ...          ...        ...
# 1324       0    1         1         1  144000.0            3          1
# 1325       1    1         0         1  360000.0            2          4
# 1326       0    0         0         0  225000.0            0          2
# 1327       1    1         0         0  270000.0            3          4
# 1328       0    1         1         0  225000.0            3          1
#
#       marital_status  housing_type   age  employed_years  work_phone  phone  \
# 0                  1             1  51.0             0.0           0      0
# 1                  1             1  37.0             2.0           1      1
# 2                  1             1  61.0             0.0           0      0
# 3                  1             1  50.0             2.0           0      1
# 4                  1             1  50.0             2.0           0      1
# ...              ...           ...   ...             ...         ...    ...
# 1324               1             1  35.0             8.0           0      0
# 1325               1             1  31.0            10.0           0      1
# 1326               3             1  28.0             3.0           0      0
# 1327               0             1  42.0             2.0           1      1
# 1328               1             1  45.0             8.0           0      0
#
#       email  family_members  label
# 0         0               2      1
# 1         0               2      1
# 2         0               2      1
# 3         1               3      1
# 4         1               3      1
# ...     ...             ...    ...
# 1324      0               3      0
# 1325      0               3      0
# 1326      0               1      0
# 1327      0               2      0
# 1328      0               2      0
#
# [1329 rows x 16 columns]

# %%
final_ml.drop(['work_phone', 'phone', 'email'], axis=1, inplace=True)

# %%
final_ml
# Out:
#       gender  car  property  children    income  income_type  education  \
# 0          1    1         1         0  180000.0            1          1
# 1          0    1         0         0  315000.0            0          1
# 2          0    0         0         0  180000.0            1          4
# 3          1    1         1         1  450000.0            0          4
# 4          1    1         1         1  450000.0            1          4
# ...      ...  ...       ...       ...       ...          ...        ...
# 1324       0    1         1         1  144000.0            3          1
# 1325       1    1         0         1  360000.0            2          4
# 1326       0    0         0         0  225000.0            0          2
# 1327       1    1         0         0  270000.0            3          4
# 1328       0    1         1         0  225000.0            3          1
#
#       marital_status  housing_type   age  employed_years  family_members  \
# 0                  1             1  51.0             0.0               2
# 1                  1             1  37.0             2.0               2
# 2                  1             1  61.0             0.0               2
# 3                  1             1  50.0             2.0               3
# 4                  1             1  50.0             2.0               3
# ...              ...           ...   ...             ...             ...
# 1324               1             1  35.0             8.0               3
# 1325               1             1  31.0            10.0               3
# 1326               3             1  28.0             3.0               1
# 1327               0             1  42.0             2.0               2
# 1328               1             1  45.0             8.0               2
#
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 1324      0
# 1325      0
# 1326      0
# 1327      0
# 1328      0
#
# [1329 rows x 13 columns]

# %% [markdown]
# ## Seprating Features & Target

# %%
features = final_ml.drop(['label'], axis=1)
target = final_ml['label']

# %% [markdown]
# ## Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.25, random_state = 10)

# %% [markdown]
# #Model Training

# %% [markdown]
# ## Model 1 - Random Forest Classification

# %%
RandomForest_model = RandomForestClassifier(n_estimators=250,          ## n_estimators= The required number of trees in the Random Forest.
                                            max_depth=12,
                                            min_samples_leaf=16)      ##  min_samples_leaf sets the minimum number of samples required to be in a leaf node

RandomForest_model.fit(x_train, y_train)

print('Random Forest Model Accuracy : ', RandomForest_model.score(x_test, y_test)*100, '%')

prediction = RandomForest_model.predict(x_test)
print('\nConfusion matrix :')
print(confusion_matrix(y_test, prediction))

print('\nClassification report:')
print(classification_report(y_test, prediction))
# Out:
# Random Forest Model Accuracy :  90.69069069069069 %
#
# Confusion matrix :
# [[302   0]
#  [ 31   0]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       302
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.91       333
#    macro avg       0.45      0.50      0.48       333
# weighted avg       0.82      0.91      0.86       333

# %% [markdown]
# ## Model 2 - XGBoost  Classification

# %%
from xgboost import XGBClassifier

XGB_model = XGBClassifier()

XGB_model.fit(x_train, y_train)

print('XGBoost Model Accuracy : ', XGB_model.score(x_test, y_test)*100, '%')

prediction = XGB_model.predict(x_test)
print('\nConfusion matrix :')
print(confusion_matrix(y_test, prediction))

print('\nClassification report:')
print(classification_report(y_test, prediction))
# Out:
# XGBoost Model Accuracy :  90.990990990991 %
#
# Confusion matrix :
# [[298   4]
#  [ 26   5]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       302
#            1       0.56      0.16      0.25        31
#
#     accuracy                           0.91       333
#    macro avg       0.74      0.57      0.60       333
# weighted avg       0.89      0.91      0.89       333

# %% [markdown]
# ## Model 3 - K Nearest Neighbor classification

# %%
knn_model = KNeighborsClassifier(n_neighbors = 9)

knn_model.fit(x_train, y_train)

print('KNN Model Accuracy : ', knn_model.score(x_test, y_test)*100, '%')

prediction = knn_model.predict(x_test)
print('\nConfusion matrix :')
print(confusion_matrix(y_test, prediction))

print('\nClassification report:')
print(classification_report(y_test, prediction))
# Out:
# KNN Model Accuracy :  90.69069069069069 %
#
# Confusion matrix :
# [[302   0]
#  [ 31   0]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       302
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.91       333
#    macro avg       0.45      0.50      0.48       333
# weighted avg       0.82      0.91      0.86       333

# %% [markdown]
# ## Model 4 - Decision Tree classification

# %%
decision_model = DecisionTreeClassifier(max_depth=12,min_samples_split=8)

decision_model.fit(x_train, y_train)

print('Decision Tree Model Accuracy : ', decision_model.score(x_test, y_test)*100, '%')

prediction = decision_model.predict(x_test)
print('\nConfusion matrix :')
print(confusion_matrix(y_test, prediction))

print('\nClassification report:')
print(classification_report(y_test, prediction))
# Out:
# Decision Tree Model Accuracy :  86.78678678678679 %
#
# Confusion matrix :
# [[286  16]
#  [ 28   3]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       302
#            1       0.16      0.10      0.12        31
#
#     accuracy                           0.87       333
#    macro avg       0.53      0.52      0.52       333
# weighted avg       0.84      0.87      0.85       333

# %% [markdown]
# ## Balancing The Dataset

# %%
MMS = MinMaxScaler()
x_train_scaled = pd.DataFrame(MMS.fit_transform(x_train), columns=x_train.columns)
x_test_scaled = pd.DataFrame(MMS.transform(x_test), columns=x_test.columns)

# %%
oversample = SMOTE()          ## Synthetic Minority Over-sampling Technique (SMOTE)

x_train_oversam, y_train_oversam = oversample.fit_resample(x_train_scaled, y_train)
x_test_oversam, y_test_oversam = oversample.fit_resample(x_test_scaled, y_test)

# %%
y_train.value_counts(normalize=True)*100
# Out:
# 0    90.863454
# 1     9.136546
# Name: label, dtype: float64

# %%
y_train_oversam.value_counts(normalize=True)*100
# Out:
# 0    50.0
# 1    50.0
# Name: label, dtype: float64

# %% [markdown]
# ## Balance Model 1 - Random Forest Classification

# %%
RandomForest_model = RandomForestClassifier(n_estimators=250,
                                            max_depth=12,
                                            min_samples_leaf=16)

RandomForest_model.fit(x_train_oversam, y_train_oversam)

print('Random Forest Model Accuracy : ', RandomForest_model.score(x_test_oversam, y_test_oversam)*100, '%')

prediction = RandomForest_model.predict(x_test_oversam)
print('\nConfusion matrix :')
print(confusion_matrix(y_test_oversam, prediction))

print('\nClassification report:')
print(classification_report(y_test_oversam, prediction))
# Out:
# Random Forest Model Accuracy :  77.98013245033113 %
#
# Confusion matrix :
# [[282  20]
#  [113 189]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.93      0.81       302
#            1       0.90      0.63      0.74       302
#
#     accuracy                           0.78       604
#    macro avg       0.81      0.78      0.77       604
# weighted avg       0.81      0.78      0.77       604

# %% [markdown]
# ## Balance Model 2 - XGBoost  classification

# %%
XGB_model = XGBClassifier()

XGB_model.fit(x_train_oversam, y_train_oversam)

print('XGBoost Model Accuracy : ', XGB_model.score(x_test_oversam, y_test_oversam)*100, '%')

prediction = XGB_model.predict(x_test_oversam)
print('\nConfusion matrix :')
print(confusion_matrix(y_test_oversam, prediction))

print('\nClassification report:')
print(classification_report(y_test_oversam, prediction))
# Out:
# XGBoost Model Accuracy :  87.91390728476821 %
#
# Confusion matrix :
# [[292  10]
#  [ 63 239]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89       302
#            1       0.96      0.79      0.87       302
#
#     accuracy                           0.88       604
#    macro avg       0.89      0.88      0.88       604
# weighted avg       0.89      0.88      0.88       604

# %% [markdown]
# ## Balance Model 3 - K Nearest Neighbor classification

# %%
knn_model = KNeighborsClassifier(n_neighbors = 7)

knn_model.fit(x_train_oversam, y_train_oversam)

print('KNN Model Accuracy : ', knn_model.score(x_test_oversam, y_test_oversam)*100, '%')

prediction = knn_model.predict(x_test_oversam)
print('\nConfusion matrix :')
print(confusion_matrix(y_test_oversam, prediction))

print('\nClassification report:')
print(classification_report(y_test_oversam, prediction))
# Out:
# KNN Model Accuracy :  58.609271523178805 %
#
# Confusion matrix :
# [[214  88]
#  [162 140]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.71      0.63       302
#            1       0.61      0.46      0.53       302
#
#     accuracy                           0.59       604
#    macro avg       0.59      0.59      0.58       604
# weighted avg       0.59      0.59      0.58       604

# %% [markdown]
# ## Balance Model 4 - Decision Tree classification

# %%
# Decision Tree classification

from sklearn.tree import DecisionTreeClassifier

decision_model = DecisionTreeClassifier(max_depth=12,min_samples_split=8)

decision_model.fit(x_train_oversam, y_train_oversam)

print('Decision Tree Model Accuracy : ', decision_model.score(x_test_oversam, y_test_oversam)*100, '%')

prediction = decision_model.predict(x_test_oversam)
print('\nConfusion matrix :')
print(confusion_matrix(y_test_oversam, prediction))

print('\nClassification report:')
print(classification_report(y_test_oversam, prediction))
# Out:
# Decision Tree Model Accuracy :  74.66887417218543 %
#
# Confusion matrix :
# [[237  65]
#  [ 88 214]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76       302
#            1       0.77      0.71      0.74       302
#
#     accuracy                           0.75       604
#    macro avg       0.75      0.75      0.75       604
# weighted avg       0.75      0.75      0.75       604

# %% [markdown]
# #Conclusion

# %% [markdown]
# #After Balancing XGBoost Model is Giving Highest Accuracy of 87.91 %, Hence We will Use XGBoost Model for Predicion.
